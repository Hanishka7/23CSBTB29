# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanishka7/23CSBTB29/blob/main/AIML_LAB1_PART3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_excel("/content/AIML_lab1_part3.xlsx")
print(data)
df=pd.DataFrame(data,columns=["Student ID"])
df
# Out:
#     Student ID Student Name  Unnamed: 2 Course  Contact Number
# 0         2110    HANISHKA          NaN    CSE      7013157239
# 1         2111      TEJASWI         NaN    EEE      6302987143
# 2         2112     SHIVANI          NaN    CSE      7680935898
# 3         2113     VARSHINI         NaN    ECE      7207440406
# 4         2114     NIHARIKA         NaN    CSE      8520883781
# 5         2115     VYSHNAVI         NaN    ECE      9154256075
# 6         2116        AJITH         NaN    ECE      6300460995
# 7         2117       RAJANI         NaN    CSE      9494265754
# 8         2118     AKSHITHA         NaN    CSE      8520065247
# 9         2119     SANWITHA         NaN    CSE      9985840108
# 10        2120       HARIKA         NaN    CSE      8074648572
# 11        2121   JOHN WESLY         NaN    CSE      8106450947
# 12        2122       DESHIK         NaN    CSE      8374901881
# 13        2123     TEJASREE         NaN    CSE      8125421928
# ...

# %%
import pandas as pd
data=pd.read_csv("heart.csv")
print(data)
df=pd.DataFrame(data,columns=("age","chol"))
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
import pandas as pd
data=pd.read_csv("games_dataset.csv")
print(data)
df=pd.DataFrame(data,columns=("Game Name","Genre"))
df
# Out:
#                                     Game Name       Genre         Platform  \
# 0                   Sekiro: Shadows Die Twice      Sports  Nintendo Switch
# 1                                     Control      Puzzle  Nintendo Switch
# 2                                    Among Us    Strategy  Nintendo Switch
# 3                Call of Duty: Modern Warfare     Stealth      PlayStation
# 4                           League of Legends  Simulation               PC
# ...                                       ...         ...              ...
# 4995  The Legend of Zelda: Breath of the Wild      Sports               PC
# 4996                Assassin's Creed Valhalla     Stealth           Mobile
# 4997             Fall Guys: Ultimate Knockout      Sports           Mobile
# 4998                            Borderlands 3  Platformer             Xbox
# 4999         Counter-Strike: Global Offensive      Action      PlayStation
#
#       Release Year  User Rating
# 0             2014     9.654719
# ...
